# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('owid-covid-data (1).csv')
df.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba  2020-03-19          NaN        NaN
# 2      ABW  North America    Aruba  2020-03-20          4.0        2.0
# 3      ABW  North America    Aruba  2020-03-21          NaN        NaN
# 4      ABW  North America    Aruba  2020-03-22          NaN        NaN
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1               0.286           NaN         NaN                  0.0  ...
# 2               0.286           NaN         0.0                  0.0  ...
# 3               0.286           NaN         NaN                  0.0  ...
# 4               0.286           NaN         NaN                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %% [markdown]
# ## Continent

# %%
df_continent = df.copy()
df_continent = df_continent['continent'].unique()
df_continent = pd.DataFrame(df_continent)
df_continent.to_csv('continent.csv', header=True)
df_continent
# Out:
#                0
# 0  North America
# 1           Asia
# 2         Africa
# 3         Europe
# 4  South America
# 5        Oceania
# 6            NaN

# %% [markdown]
# ## Country

# %%
temp = list(df_continent[0])
def set_key(countryName):
    return temp.index(countryName) + 1

df_country = df.copy()
df_country = df_country[['location', 'continent']]
df_country = df_country.drop_duplicates(subset=None, keep='first', inplace=False)
# df_country = pd.DataFrame(df_country)
df_country['con-id'] = np.vectorize(set_key)(df_country['continent'])
df_country.to_csv('country.csv', header=True)
df_country.head()
# Out:
#          location      continent  con-id
# 0           Aruba  North America       1
# 244   Afghanistan           Asia       2
# 566        Angola         Africa       3
# 806      Anguilla  North America       1
# 1041      Albania         Europe       4

# %% [markdown]
# ## TotalCases

# %%
df_cases = df.copy()
df_cty_id = df_country.copy()
df_cty_id = df_cty_id.reset_index().reset_index().drop('index', axis=1)
cty_id = list(df_cty_id['location'])
def set_key(countryName):
    return cty_id.index(countryName) + 1

df_cases = df_cases[['total_cases', 'date', 'location']]
df_cases['cty_id'] = np.vectorize(set_key)(df_cases['location'])
df_cases = df_cases
df_cases.to_csv('totalcases.csv', header=True)
df_cases.head()
# Out:
#    total_cases        date location  cty_id
# 0          2.0  2020-03-13    Aruba       1
# 1          NaN  2020-03-19    Aruba       1
# 2          4.0  2020-03-20    Aruba       1
# 3          NaN  2020-03-21    Aruba       1
# 4          NaN  2020-03-22    Aruba       1

# %% [markdown]
# ## New Cases

# %%
df_new_cases = df.copy()
df_cty_id = df_country.copy()
df_cty_id = df_cty_id.reset_index().reset_index().drop('index', axis=1)
cty_id = list(df_cty_id['location'])
def set_key(countryName):
    return cty_id.index(countryName) + 1

df_new_cases = df_new_cases[['new_cases', 'new_cases_smoothed', 'date', 'location']]
df_new_cases['cty_id'] = np.vectorize(set_key)(df_new_cases['location'])
df_new_cases = df_new_cases.fillna(0)
df_new_cases.to_csv('newcases.csv', header=True)
df_new_cases.head()
# Out:
#    new_cases  new_cases_smoothed        date location  cty_id
# 0        2.0               0.000  2020-03-13    Aruba       1
# 1        0.0               0.286  2020-03-19    Aruba       1
# 2        2.0               0.286  2020-03-20    Aruba       1
# 3        0.0               0.286  2020-03-21    Aruba       1
# 4        0.0               0.286  2020-03-22    Aruba       1

# %% [markdown]
# ## Total Tests

# %%
df_tests = df.copy()
df_cty_id = df_country.copy()
df_cty_id = df_cty_id.reset_index().reset_index().drop('index', axis=1)
cty_id = list(df_cty_id['location'])
def set_key(countryName):
    return cty_id.index(countryName) + 1

df_tests = df_tests[['total_tests', 'date', 'location']]
df_tests['cty_id'] = np.vectorize(set_key)(df_tests['location'])
df_tests = df_tests
df_tests.to_csv('totaltests.csv', header=True)
df_tests.head()
# Out:
#    total_tests        date location  cty_id
# 0          NaN  2020-03-13    Aruba       1
# 1          NaN  2020-03-19    Aruba       1
# 2          NaN  2020-03-20    Aruba       1
# 3          NaN  2020-03-21    Aruba       1
# 4          NaN  2020-03-22    Aruba       1

# %% [markdown]
# ## New Tests

# %%
df_new_tests = df.copy()
df_cty_id = df_country.copy()
df_cty_id = df_cty_id.reset_index().reset_index().drop('index', axis=1)
cty_id = list(df_cty_id['location'])
def set_key(countryName):
    return cty_id.index(countryName) + 1

df_new_tests = df_new_tests[['new_tests', 'new_tests_smoothed', 'date', 'location']]
df_new_tests['cty_id'] = np.vectorize(set_key)(df_new_tests['location'])
df_new_tests = df_new_tests.fillna(0)
df_new_tests.to_csv('newtests.csv', header=True)
df_new_tests.head()
# Out:
#    new_tests  new_tests_smoothed        date location  cty_id
# 0        0.0                 0.0  2020-03-13    Aruba       1
# 1        0.0                 0.0  2020-03-19    Aruba       1
# 2        0.0                 0.0  2020-03-20    Aruba       1
# 3        0.0                 0.0  2020-03-21    Aruba       1
# 4        0.0                 0.0  2020-03-22    Aruba       1

# %% [markdown]
# ## Stringency Index

# %%
df_stringency = df.copy()
df_cty_id = df_country.copy()
df_cty_id = df_cty_id.reset_index().reset_index().drop('index', axis=1)
cty_id = list(df_cty_id['location'])
def set_key(countryName):
    return cty_id.index(countryName) + 1

df_stringency = df_stringency[['stringency_index', 'date', 'location']]
df_stringency['cty_id'] = np.vectorize(set_key)(df_stringency['location'])
df_stringency = df_stringency#.fillna(0)
df_stringency.to_csv('stringency.csv', header=True)
df_stringency.head()
# Out:
#    stringency_index        date location  cty_id
# 0              0.00  2020-03-13    Aruba       1
# 1             33.33  2020-03-19    Aruba       1
# 2             33.33  2020-03-20    Aruba       1
# 3             44.44  2020-03-21    Aruba       1
# 4             44.44  2020-03-22    Aruba       1

# %% [markdown]
# ## Total Deaths

# %%
df_deaths = df.copy()
df_cty_id = df_country.copy()
df_cty_id = df_cty_id.reset_index().reset_index().drop('index', axis=1)
cty_id = list(df_cty_id['location'])
def set_key(countryName):
    return cty_id.index(countryName) + 1

df_deaths = df_deaths[['total_deaths', 'date', 'location']]
df_deaths['cty_id'] = np.vectorize(set_key)(df_deaths['location'])
df_deaths = df_deaths
df_deaths.to_csv('totaldeaths.csv', header=True)
df_deaths.head()
# Out:
#    total_deaths        date location  cty_id
# 0           NaN  2020-03-13    Aruba       1
# 1           NaN  2020-03-19    Aruba       1
# 2           NaN  2020-03-20    Aruba       1
# 3           NaN  2020-03-21    Aruba       1
# 4           NaN  2020-03-22    Aruba       1

# %% [markdown]
# ## New Deaths

# %%
df_new_deaths = df.copy()
df_cty_id = df_country.copy()
df_cty_id = df_cty_id.reset_index().reset_index().drop('index', axis=1)
cty_id = list(df_cty_id['location'])
def set_key(countryName):
    return cty_id.index(countryName) + 1

df_new_deaths = df_new_deaths[['new_deaths', 'new_deaths_smoothed', 'date', 'location']]
df_new_deaths['cty_id'] = np.vectorize(set_key)(df_new_deaths['location'])
df_new_deaths = df_new_deaths.fillna(0)
df_new_deaths.to_csv('newdeaths.csv', header=True)
df_new_deaths.head()
# Out:
#    new_deaths  new_deaths_smoothed        date location  cty_id
# 0         0.0                  0.0  2020-03-13    Aruba       1
# 1         0.0                  0.0  2020-03-19    Aruba       1
# 2         0.0                  0.0  2020-03-20    Aruba       1
# 3         0.0                  0.0  2020-03-21    Aruba       1
# 4         0.0                  0.0  2020-03-22    Aruba       1

# %% [markdown]
# ## hospital_beds_per_thousand

# %%
df_bedsperthousand = df.copy()
df_cty_id = df_country.copy()
df_cty_id = df_cty_id.reset_index().reset_index().drop('index', axis=1)
cty_id = list(df_cty_id['location'])
def set_key(countryName):
    return cty_id.index(countryName) + 1

df_bedsperthousand = df_bedsperthousand[['hospital_beds_per_thousand', 'date', 'location']]
df_bedsperthousand['cty_id'] = np.vectorize(set_key)(df_bedsperthousand['location'])
df_bedsperthousand = df_bedsperthousand.dropna()
df_bedsperthousand.to_csv('hospbedsperthousand.csv', header=True)
df_bedsperthousand.head()
# Out:
#      hospital_beds_per_thousand        date     location  cty_id
# 244                         0.5  2019-12-31  Afghanistan       2
# 245                         0.5  2020-01-01  Afghanistan       2
# 246                         0.5  2020-01-02  Afghanistan       2
# 247                         0.5  2020-01-03  Afghanistan       2
# 248                         0.5  2020-01-04  Afghanistan       2

# %% [markdown]
# ## handwashing_facilities

# %%
df_handwashing = df.copy()
df_cty_id = df_country.copy()
df_cty_id = df_cty_id.reset_index().reset_index().drop('index', axis=1)
cty_id = list(df_cty_id['location'])
def set_key(countryName):
    return cty_id.index(countryName) + 1

df_handwashing = df_handwashing[['handwashing_facilities', 'date', 'location']]
df_handwashing['cty_id'] = np.vectorize(set_key)(df_handwashing['location'])
df_handwashing = df_handwashing.dropna()
df_handwashing.to_csv('handwashing.csv', header=True)
df_handwashing.head()
# Out:
#      handwashing_facilities        date     location  cty_id
# 244                  37.746  2019-12-31  Afghanistan       2
# 245                  37.746  2020-01-01  Afghanistan       2
# 246                  37.746  2020-01-02  Afghanistan       2
# 247                  37.746  2020-01-03  Afghanistan       2
# 248                  37.746  2020-01-04  Afghanistan       2

# %%
df_handwashing = df.copy()
df_cty_id = df_country.copy()
df_cty_id = df_cty_id.reset_index().reset_index().drop('index', axis=1)
cty_id = list(df_cty_id['location'])
def set_key(countryName):
    return cty_id.index(countryName) + 1

df_handwashing = df_handwashing[['handwashing_facilities', 'date', 'location']]
df_handwashing['cty_id'] = np.vectorize(set_key)(df_handwashing['location'])
df_handwashing = df_handwashing[(df_handwashing['date'] >= '2020-03-01') & (df_handwashing['date'] < '2020-04-01')]
df_handwashing['location'].unique()
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Anguilla', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Armenia',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh', 'Bulgaria',
#        'Bahrain', 'Bahamas', 'Bosnia and Herzegovina', 'Belarus',
#        'Belize', 'Bermuda', 'Bolivia', 'Brazil', 'Barbados', 'Brunei',
#        'Bhutan', 'Central African Republic', 'Canada', 'Switzerland',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon',
#        'Democratic Republic of Congo', 'Congo', 'Colombia', 'Cape Verde',
#        'Costa Rica', 'Cuba', 'Curacao', 'Cayman Islands', 'Cyprus',
#        'Czech Republic', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
#        'Dominican Republic', 'Algeria', 'Ecuador', 'Egypt', 'Eritrea',
#        'Spain', 'Estonia', 'Ethiopia', 'Finland', 'Fiji', 'France',
#        'Faeroe Islands', 'Gabon', 'United Kingdom', 'Georgia', 'Guernsey',
# ...
